# %% [markdown]
# **AIM : Numerical Computation with NumPy: Perform different computations using NumPy library.**

# %% [markdown]
# **NAME - VAISHALI KALAPAD**
#
# **ROLL NO. - SYA-49**

# %% [markdown]
# **Theory :**
#
# 1. Explain the role of NumPy in the Python scientific computing ecosystem?
#
# NumPy is fundamental to the Python scientific computing ecosystem. It provides the `ndarray` object, a high-performance, multi-dimensional array, which is significantly more efficient than standard Python lists for numerical operations. This array structure serves as the foundation for many other powerful libraries like Pandas, Matplotlib, and Scikit-learn, enabling efficient storage, manipulation, and processing of large datasets crucial for data science, machine learning, and scientific research.
#
# 2. Why is NumPy considered faster than pure Python computations?
#
# NumPy is faster than pure Python computations primarily due to its implementation in C and Fortran, which are compiled languages. This allows NumPy to perform operations on arrays in contiguous blocks of memory, leading to better cache utilization. Crucially, NumPy leverages *vectorization*, executing operations on entire arrays at once without explicit Python loops, which dramatically reduces overhead and improves performance compared to element-wise operations in pure Python.
#
# 3. What types of mathematical operations can be performed using NumPy?
#
# NumPy supports a comprehensive range of mathematical operations. These include basic element-wise arithmetic (addition, subtraction, multiplication, division), advanced mathematical functions (e.g., `np.sin()`, `np.exp()`, `np.log()`), statistical operations (e.g., `np.mean()`, `np.median()`, `np.std()`, `np.sum()`, `np.min()`, `np.max()`), and fundamental linear algebra functions (e.g., matrix multiplication with `np.dot()` or `@` operator, `np.linalg.det()` for determinants, `np.linalg.solve()` for systems of linear equations). It also provides Fourier transforms, random number generation, and more complex numerical routines.
#
# 4. Explain indexing and slicing in NumPy arrays?
#
# Indexing in NumPy arrays refers to accessing individual elements using their position (e.g., `arr[0]` for the first element). Slicing, on the other hand, is the process of extracting a contiguous subset of elements from an array using a range of indices (e.g., `arr[1:4]` selects elements from index 1 up to, but not including, index 4). Both methods support one-dimensional and multi-dimensional arrays, allowing for flexible and efficient data retrieval and manipulation without copying the entire array.
#
# 5. How does NumPy integrate with libraries like Pandas, Matplotlib, and Scikit-learn?
#
# NumPy integrates seamlessly with other core Python scientific libraries, making it a foundational component of the data science stack. Pandas DataFrames and Series are built upon NumPy arrays, allowing for efficient tabular data manipulation. Matplotlib uses NumPy arrays as the primary data structure for plotting and visualizing numerical data. Scikit-learn, a machine learning library, relies heavily on NumPy arrays for representing datasets, performing numerical computations in algorithms, and handling model inputs/outputs. This deep integration ensures efficient data exchange and high-performance computation across the ecosystem.

# %% [markdown]
# Import NumPy

# %%
import numpy as np

# %% [markdown]
# NmPy vs Python Speed Comparsion
#
# This cell compares the execution speed of pure Python and NumPy. First, a Python list is created and each element is multiplied by 2 using a loop-like operation (list comprehension). Then, a NumPy array is created and multiplied by 2 using vectorized operations. The time module is used to measure the execution time for both approaches. This demonstrates that NumPy is faster because it performs operations at a lower level using optimized code and avoids explicit loops.

# %%
import time
import numpy as np
# Python list computation
start = time.time()
lst = list(range(1000000))
lst = [x * 2 for x in lst]
end = time.time()
print("Python Time:", end - start)

# NumPy computation
start = time.time()
arr = np.arange(1000000)
arr = arr * 2
end = time.time()
print("NumPy Time:", end - start)
# Out:
# Python Time: 0.10830473899841309
# NumPy Time: 0.010436773300170898

# %% [markdown]
# Basic Mathematical Operations
#
# In this cell, a NumPy array is created and basic arithmetic operations such as addition, subtraction, multiplication, and division are performed on it. These operations are applied element-wise, meaning each element in the array is processed individually. This shows how NumPy simplifies mathematical computations and allows operations to be performed on entire datasets efficiently.

# %%
arr = np.array([10, 20, 30, 40, 50])

print("Original Array:", arr)
print("Addition:", arr + 2)
print("Subtraction:", arr - 1)
print("Multiplication:", arr * 3)
print("Division:", arr / 2)
# Out:
# Original Array: [10 20 30 40 50]
# Addition: [12 22 32 42 52]
# Subtraction: [ 9 19 29 39 49]
# Multiplication: [ 30  60  90 120 150]
# Division: [ 5. 10. 15. 20. 25.]

# %% [markdown]
# Advanced Mathematical Functions
#
# This cell demonstrates advanced mathematical and statistical functions provided by NumPy. Functions like sqrt() calculate square roots, power() raises elements to a specified power, and statistical functions like mean(), median(), and std() compute important measures of central tendency and dispersion. These built-in functions make NumPy highly useful for data analysis and scientific computing.

# %%
print("Square Root:", np.sqrt(arr))
print("Power:", np.power(arr, 2))
print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Square Root: [3.16227766 4.47213595 5.47722558 6.32455532 7.07106781]
# Power: [ 100  400  900 1600 2500]
# Mean: 30.0
# Median: 30.0
# Standard Deviation: 14.142135623730951

# %% [markdown]
# Indexing and Slicing (1D Array)
#
# This cell explains how to access elements in a one-dimensional NumPy array using indexing and slicing. Indexing is used to retrieve a specific element by its position,
#
# while slicing is used to extract a subset of elements using a range. For example, arr[1:4] returns elements from index 1 to 3. This helps in efficiently working with subsets of data.

# %%
arr = np.array([1, 2, 3, 4, 5])

print("First Element:", arr[0])
print("Last Element:", arr[-1])
print("Slice (1 to 3):", arr[1:4])
# Out:
# First Element: 1
# Last Element: 5
# Slice (1 to 3): [2 3 4]

# %% [markdown]
# Indexing in 2D Array
#
# In this cell, a two-dimensional NumPy array (matrix) is created, and different indexing techniques are demonstrated. Elements can be accessed using row and column indices, such as arr2[1, 2]. Additionally, entire rows or columns can be extracted using slicing. This is useful when working with structured data like tables or matrices

# %%
arr2 = np.array([[10, 20, 30],
                 [40, 50, 60]])

print("Element at row 1, col 2:", arr2[1, 2])
print("First Row:", arr2[0])
print("Second Column:", arr2[:, 1])
# Out:
# Element at row 1, col 2: 60
# First Row: [10 20 30]
# Second Column: [20 50]

# %% [markdown]
# NumPy with Pandas
#
# This cell shows how NumPy integrates with the Pandas library. A NumPy array is created and then converted into a Pandas DataFrame. Pandas uses NumPy arrays internally, making data manipulation efficient. This integration allows users to easily move data between NumPy and Pandas for analysis and processing.

# %%
import pandas as pd

data = np.array([10, 20, 30, 40, 50])
df = pd.DataFrame(data, columns=["Values"])
print(df)
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %% [markdown]
# NumPy with Matplotlib
#
# In this cell, a NumPy array is used to create a simple line plot using Matplotlib. The array values are plofled on a graph, and labels are added for befler visualization. This demonstrates how NumPy works with Matplotlib to visualize numerical data, which is important for data analysis and interpretation.

# %%
import matplotlib.pyplot as plt
data = np.array([1, 2, 3, 4, 5])
plt.plot(data)
plt.title("NumPy Data Plot")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# NumPy with Scikit-learn
#
# This cell demonstrates how NumPy is used with Scikit-learn for machine learning tasks. A dataset is created using NumPy arrays, and a Linear Regression model is trained using this data. The model then predicts a new value based on input. This
#
# shows how NumPy provides the data structure required for machine learning algorithms in Scikit-learn.

# %%
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

# Model
model = LinearRegression()
model.fit(X, y)

# Prediction
prediction = model.predict([[6]])
print("Prediction for 6:", prediction)
# Out:
# Prediction for 6: [12.]

# %% [markdown]
# **conclusion -**
#
# This effectively demonstrates the core functionalities and benefits of NumPy, including its speed advantages over pure Python, its extensive mathematical capabilities, and its seamless integration with other essential libraries like Pandas, Matplotlib, and Scikit-learn. These examples highlight NumPy's crucial role as a foundational library in the Python scientific computing ecosystem for data manipulation, analysis, and machine learning.
