# %% [markdown]
# **AIM:
# Data Wrangling with pandas: Manipulate and transform data to suit the analysis
# needs.**

# %% [markdown]
# **Theory**
#
# 1. What is Data Wrangling? Explain the difference between Data Wrangling and Data Preprocessing.
#
# Data wrangling refers to the process of cleaning, transforming, and arranging raw data into a well-structured format so it can be easily analyzed. In real-life scenarios, data is often messy, incomplete, or contains errors, so data wrangling helps improve its quality by fixing missing values, removing duplicates, and converting data into a proper format.
#
# Data wrangling and data preprocessing differ in their purpose and when they are used. Data wrangling is mainly focused on preparing raw data for analysis by organizing and cleaning it. On the other hand, data preprocessing is used to prepare data specifically for machine learning models. It involves techniques like scaling, normalization, and encoding.
#
# In short, data wrangling makes the data ready for analysis, while data preprocessing prepares it for building and training models.
#
# 2. What is the importance of Exploratory Data Analysis (EDA) in Pandas?
#
# Exploratory Data Analysis (EDA) is a key step in data analysis that helps us understand the dataset and its main features. It is used to find missing values, recognize patterns and relationships, and identify any unusual values or errors. By performing EDA, we can better understand the data before moving on to advanced analysis or model building.
#
# In Pandas, functions like head(), info(), and describe() are widely used for EDA. These functions help in viewing the dataset, checking data types, and getting a summary of statistical details. Overall, EDA helps in making better decisions and ensures that the data is properly prepared for further analysis.
#
# 3. What are the main differences between Series, DataFrame, and Panel?
#
# In Pandas, Series, DataFrame, and Panel are different data structures used to store and work with data. A Series is a one-dimensional structure that holds data of any type and is similar to a single column. A DataFrame is a two-dimensional structure with rows and columns, which makes it ideal for handling tabular data and performing analysis.
#
# A Panel is a three-dimensional data structure that was used for working with multi-dimensional data. However, it is now deprecated and not commonly used in recent versions of Pandas. In short, Series is used for simple one-dimensional data, DataFrame is the most commonly used structure for analysis, and Panel was used for higher-dimensional data.
#
# 4. Explain the use of isnull(), notnull(), dropna(), and fillna().
#
# In Pandas, there are different functions available to manage missing data. The isnull() function helps identify missing values by returning True for those entries. In contrast, notnull() returns True for values that are present.
#
# The dropna() function is used to remove rows or columns that contain missing values, especially when those missing entries are not very important. On the other hand, fillna() is used to replace missing values with a specific value, such as an average, median, or a fixed number.
#
# These functions are very important for data cleaning and help ensure that the analysis results are accurate and reliable.
#
# 5. What is column transformation and why is it important in data analysis?
#
# Column transformation refers to modifying existing columns or creating new ones in a dataset to make the data more useful for analysis. This can include tasks like changing data types, generating new columns from existing data, performing calculations, and converting categorical values into numerical form.
#
# It is important because it improves the quality and consistency of data, making it easier to analyze. It also helps in preparing the dataset for machine learning models and makes results easier to understand and visualize. Overall, column transformation is an essential step in effective data analysis.

# %%
import pandas as pd
import numpy as np
# Create Dataset (Raw data with missing values)
data = {
    'Name': ['Arnav', 'Raj', 'Jai', 'Sahil', 'Dhiraj'],
    'Age': [21, 20, np.nan, 24, 25],
    'Marks': [85, np.nan, 78, 92, 88]
}

df = pd.DataFrame(data)
print("Original Dataset:")
print(df)

#Exploratory Data Analysis (EDA)
print("\nFirst 5 rows:")
print(df.head())

print("\nDataset Information:")
print(df.info())

print("\nStatistical Summary:")
print(df.describe())

#Check missing value
print("\nMissing Values (True = Missing):")
print(df.isnull())

print("\nCount of Missing Values:")
print(df.isnull().sum())

#Use of notnull()
print("\nNon-Missing Values (True = Present):")
print(df.notnull())

#Remove Missing Values using dropna()
df_drop = df.dropna()

print("\nDataset after removing missing values:")
print(df_drop)

# Fill Age with mean
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Fill Marks with mean
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())

print("\nDataset after filling missing values:")
print(df)

#Column Transformation
# Create new column
df['Total'] = df['Marks'] + 10

# Convert datatype of Age to integer
df['Age'] = df['Age'].astype(int)

print("\nDataset after column transformation:")
print(df)
# Out:
# Original Dataset:
#      Name   Age  Marks
# 0   Arnav  21.0   85.0
# 1     Raj  20.0    NaN
# 2     Jai   NaN   78.0
# 3   Sahil  24.0   92.0
# 4  Dhiraj  25.0   88.0
#
# First 5 rows:
#      Name   Age  Marks
# 0   Arnav  21.0   85.0
# 1     Raj  20.0    NaN
# 2     Jai   NaN   78.0
# 3   Sahil  24.0   92.0
# 4  Dhiraj  25.0   88.0
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     4 non-null      float64
#  2   Marks   4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 252.0+ bytes
# None
#
# Statistical Summary:
#              Age      Marks
# count   4.000000   4.000000
# mean   22.500000  85.750000
# std     2.380476   5.909033
# min    20.000000  78.000000
# 25%    20.750000  83.250000
# 50%    22.500000  86.500000
# 75%    24.250000  89.000000
# ...

# %% [markdown]
# ### **Data Wrangling Using IRIS Dataset**

# %%
import pandas as pd
import numpy as np

# %%
# Load dataset from URL
url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# First 5 rows
df.head()

# Last 5 rows
df.tail()

# Dataset information
df.info()

# Statistical summary
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Introduce missing values manually
df.loc[0, 'sepal_length'] = np.nan
df.loc[1, 'petal_width'] = np.nan

df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     0
# petal_length    0
# petal_width     1
# species         0
# dtype: int64

# %%
# Fill missing values with mean
df['sepal_length'].fillna(df['sepal_length'].mean(), inplace=True)
df['petal_width'].fillna(df['petal_width'].mean(), inplace=True)

df.isnull().sum()

# %%
df.notnull().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0          True         True          True         True     True
# 1          True         True          True         True     True
# 2          True         True          True         True     True
# 3          True         True          True         True     True
# 4          True         True          True         True     True

# %%
# Create new column
df['sepal_area'] = df['sepal_length'] * df['sepal_width']

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_area
# 0      5.848322          3.5           1.4     0.200000  setosa   20.469128
# 1      4.900000          3.0           1.4     1.205369  setosa   14.700000
# 2      4.700000          3.2           1.3     0.200000  setosa   15.040000
# 3      4.600000          3.1           1.5     0.200000  setosa   14.260000
# 4      5.000000          3.6           1.4     0.200000  setosa   18.000000

# %%
# Filter rows where sepal_length > 5
df[df['sepal_length'] > 5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0        5.848322          3.5           1.4          0.2     setosa
# 5        5.400000          3.9           1.7          0.4     setosa
# 10       5.400000          3.7           1.5          0.2     setosa
# 14       5.800000          4.0           1.2          0.2     setosa
# 15       5.700000          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145      6.700000          3.0           5.2          2.3  virginica
# 146      6.300000          2.5           5.0          1.9  virginica
# 147      6.500000          3.0           5.2          2.0  virginica
# 148      6.200000          3.4           5.4          2.3  virginica
# 149      5.900000          3.0           5.1          1.8  virginica
#
#      sepal_area
# 0     20.469128
# 5     21.060000
# 10    19.980000
# 14    23.200000
# 15    25.080000
# ..          ...
# ...

# %%
# Average values by species
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  sepal_area
# species
# setosa          5.020966        3.418         1.464     0.264107   17.261183
# versicolor      5.936000        2.770         4.260     1.326000   16.526200
# virginica       6.588000        2.974         5.552     2.026000   19.684600

# %%
# Sort by sepal_length
df.sort_values(by='sepal_length', ascending=False).head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 131           7.9          3.8           6.4          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
#
#      sepal_area
# 131       30.02
# 122       21.56
# 118       20.02
# 117       29.26
# 135       23.10

# %%
print("Final Dataset:")
df.head()
# Out:
# Final Dataset:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_area
# 0      5.848322          3.5           1.4     0.200000  setosa   20.469128
# 1      4.900000          3.0           1.4     1.205369  setosa   14.700000
# 2      4.700000          3.2           1.3     0.200000  setosa   15.040000
# 3      4.600000          3.1           1.5     0.200000  setosa   14.260000
# 4      5.000000          3.6           1.4     0.200000  setosa   18.000000

# %% [markdown]
# ### **Conclusion**
# In this practical, data wrangling was carried out on the Iris dataset using Pandas. Exploratory Data Analysis (EDA) was performed to study the dataset and understand its structure and features. Missing values were detected and managed using functions such as isnull() and fillna(). Column transformation methods were also used to create new features and enhance the quality of the data. As a result, the dataset became clean, well-structured, and ready for further analysis.
